# %%
# połączenia colaba z drivem
from google.colab import drive

# %%
ROOT = '/content/drive'
drive.mount(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
HOME = ROOT + '/My drive/Colab Notebooks'
HOME
# Out:
# '/content/drive/My drive/Colab Notebooks'

# %%
# !mkdir -p "{HOME}"
# Out:
# mkdir: cannot create directory ‘/content/drive/My drive’: Operation not supported

# %%
cd '/content/drive/My Drive/Colab Notebooks/challenge/Korona'
# Out:
# /content/drive/My Drive/Colab Notebooks/challenge/Korona

# %%
GITHUB_TOKEN = 'a8d068a075ebc2c6a1b1549996dfb8b1f254b2b7'

GITHUB_URL = 'https://{0}@github.com/eb-art/crown.git'.format(GITHUB_TOKEN)

# %%
# !git clone {GITHUB_URL}
# Out:
# Cloning into 'crown'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
ls
# Out:
# crown/  Crown.ipynb

# %%
# tworzenie nowego notebooka
# File -> new notebook

# %%
# !git add Crown.ipynb
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
